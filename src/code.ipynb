# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import calendar
import os
import time

# %% [markdown]
# Część 1:
# Pobieranie danych

# %%
output_dir = "../pobrane"
output_dir_unzip = "../pobrane_unzip"

os.makedirs(output_dir, exist_ok=True)
os.makedirs(output_dir_unzip, exist_ok=True)

for year in range(2001, 2024):
    for month in range(1, 13):
        filename = f"dane_{year}_{month:02d}.zip"
        url = f"https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/{year}/{year}_{month:02d}_k.zip"

        print(f"Pobieranie: {url}")

        os.system(f'powershell Invoke-WebRequest -Uri "{url}" -OutFile "{output_dir}/{filename}"')
        os.system(f'powershell Expand-Archive -Path "{output_dir}/{filename}" -Force -DestinationPath "{output_dir_unzip}"')
        time.sleep(1)

        for file in os.listdir(f"{output_dir_unzip}"):
            if file.startswith('k_d_t'):
                os.remove(f"{output_dir_unzip}/{file}")
# Out:
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2001/2001_01_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2001/2001_02_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2001/2001_03_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2001/2001_04_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2001/2001_05_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2001/2001_06_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2001/2001_07_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2001/2001_08_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2001/2001_09_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2001/2001_10_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2001/2001_11_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2001/2001_12_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2002/2002_01_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2002/2002_02_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2002/2002_03_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2002/2002_04_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2002/2002_05_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2002/2002_06_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2002/2002_07_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2002/2002_08_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2002/2002_09_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2002/2002_10_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2002/2002_11_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2002/2002_12_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2003/2003_01_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2003/2003_02_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2003/2003_03_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2003/2003_04_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2003/2003_05_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2003/2003_06_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2003/2003_07_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2003/2003_08_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2003/2003_09_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2003/2003_10_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2003/2003_11_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2003/2003_12_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2004/2004_01_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2004/2004_02_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2004/2004_03_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2004/2004_04_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2004/2004_05_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2004/2004_06_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2004/2004_07_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2004/2004_08_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2004/2004_09_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2004/2004_10_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2004/2004_11_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2004/2004_12_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2005/2005_01_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2005/2005_02_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2005/2005_03_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2005/2005_04_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2005/2005_05_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2005/2005_06_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2005/2005_07_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2005/2005_08_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2005/2005_09_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2005/2005_10_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2005/2005_11_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2005/2005_12_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2006/2006_01_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2006/2006_02_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2006/2006_03_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2006/2006_04_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2006/2006_05_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2006/2006_06_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2006/2006_07_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2006/2006_08_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2006/2006_09_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2006/2006_10_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2006/2006_11_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2006/2006_12_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2007/2007_01_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2007/2007_02_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2007/2007_03_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2007/2007_04_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2007/2007_05_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2007/2007_06_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2007/2007_07_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2007/2007_08_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2007/2007_09_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2007/2007_10_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2007/2007_11_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2007/2007_12_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2008/2008_01_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2008/2008_02_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2008/2008_03_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2008/2008_04_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2008/2008_05_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2008/2008_06_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2008/2008_07_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2008/2008_08_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2008/2008_09_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2008/2008_10_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2008/2008_11_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2008/2008_12_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2009/2009_01_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2009/2009_02_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2009/2009_03_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2009/2009_04_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2009/2009_05_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2009/2009_06_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2009/2009_07_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2009/2009_08_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2009/2009_09_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2009/2009_10_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2009/2009_11_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2009/2009_12_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2010/2010_01_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2010/2010_02_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2010/2010_03_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2010/2010_04_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2010/2010_05_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2010/2010_06_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2010/2010_07_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2010/2010_08_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2010/2010_09_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2010/2010_10_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2010/2010_11_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2010/2010_12_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2011/2011_01_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2011/2011_02_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2011/2011_03_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2011/2011_04_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2011/2011_05_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2011/2011_06_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2011/2011_07_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2011/2011_08_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2011/2011_09_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2011/2011_10_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2011/2011_11_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2011/2011_12_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2012/2012_01_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2012/2012_02_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2012/2012_03_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2012/2012_04_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2012/2012_05_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2012/2012_06_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2012/2012_07_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2012/2012_08_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2012/2012_09_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2012/2012_10_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2012/2012_11_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2012/2012_12_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2013/2013_01_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2013/2013_02_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2013/2013_03_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2013/2013_04_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2013/2013_05_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2013/2013_06_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2013/2013_07_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2013/2013_08_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2013/2013_09_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2013/2013_10_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2013/2013_11_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2013/2013_12_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2014/2014_01_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2014/2014_02_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2014/2014_03_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2014/2014_04_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2014/2014_05_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2014/2014_06_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2014/2014_07_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2014/2014_08_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2014/2014_09_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2014/2014_10_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2014/2014_11_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2014/2014_12_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2015/2015_01_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2015/2015_02_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2015/2015_03_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2015/2015_04_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2015/2015_05_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2015/2015_06_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2015/2015_07_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2015/2015_08_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2015/2015_09_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2015/2015_10_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2015/2015_11_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2015/2015_12_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2016/2016_01_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2016/2016_02_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2016/2016_03_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2016/2016_04_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2016/2016_05_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2016/2016_06_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2016/2016_07_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2016/2016_08_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2016/2016_09_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2016/2016_10_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2016/2016_11_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2016/2016_12_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2017/2017_01_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2017/2017_02_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2017/2017_03_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2017/2017_04_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2017/2017_05_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2017/2017_06_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2017/2017_07_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2017/2017_08_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2017/2017_09_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2017/2017_10_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2017/2017_11_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2017/2017_12_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2018/2018_01_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2018/2018_02_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2018/2018_03_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2018/2018_04_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2018/2018_05_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2018/2018_06_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2018/2018_07_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2018/2018_08_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2018/2018_09_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2018/2018_10_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2018/2018_11_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2018/2018_12_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2019/2019_01_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2019/2019_02_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2019/2019_03_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2019/2019_04_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2019/2019_05_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2019/2019_06_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2019/2019_07_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2019/2019_08_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2019/2019_09_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2019/2019_10_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2019/2019_11_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2019/2019_12_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2020/2020_01_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2020/2020_02_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2020/2020_03_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2020/2020_04_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2020/2020_05_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2020/2020_06_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2020/2020_07_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2020/2020_08_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2020/2020_09_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2020/2020_10_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2020/2020_11_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2020/2020_12_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2021/2021_01_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2021/2021_02_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2021/2021_03_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2021/2021_04_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2021/2021_05_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2021/2021_06_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2021/2021_07_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2021/2021_08_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2021/2021_09_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2021/2021_10_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2021/2021_11_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2021/2021_12_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2022/2022_01_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2022/2022_02_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2022/2022_03_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2022/2022_04_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2022/2022_05_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2022/2022_06_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2022/2022_07_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2022/2022_08_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2022/2022_09_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2022/2022_10_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2022/2022_11_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2022/2022_12_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2023/2023_01_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2023/2023_02_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2023/2023_03_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2023/2023_04_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2023/2023_05_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2023/2023_06_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2023/2023_07_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2023/2023_08_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2023/2023_09_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2023/2023_10_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2023/2023_11_k.zip
# Pobieranie: https://danepubliczne.imgw.pl/data/dane_pomiarowo_obserwacyjne/dane_meteorologiczne/dobowe/klimat/2023/2023_12_k.zip

# %% [markdown]
# Część 1:
# Scalanie danych

# %%
output = r"../data/data.csv"
base_dir = r"../pobrane_unzip"

folder_path = os.path.dirname(output)
os.makedirs(folder_path, exist_ok=True)
first = True

for year in range(2001, 2024):
    for month in range(1, 13):
        plik = f"k_d_{month:02d}_{year}.csv"
        folder = os.path.join(base_dir, plik)

        if os.path.exists(folder):
            df = pd.read_csv(folder, header=None, encoding='cp1250')

            df.to_csv(
                output,
                mode="w" if first else "a",
                index=False,
                header=None,
                encoding='utf-8'
            )
            first = False

# %% [markdown]
# Część 1:
# Usunięcie niepotrzebnych kolumn

# %%
df = pd.read_csv(output, header=None, usecols=[1, 2, 3, 4, 5, 7, 9])
df.to_csv(
                output,
                mode="w",
                index=False,
                header=None,
            )
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df = pd.read_csv(output, header=None, usecols=[1, 2, 3, 4, 5, 7, 9])
#       2 df.to_csv(
#       3                 output,
#       4                 mode="w",
#       5                 index=False,
#       6                 header=None,
#       7             )
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\parsers\readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\parsers\readers.py:1923, in TextFileReader.read(self, nrows)
#    1916 nrows = validate_integer("nrows", nrows)
#    1917 try:
#    1918     # error: "ParserBase" has no attribute "read"
#    1919     (
#    1920         index,
#    1921         columns,
#    1922         col_dict,
# -> 1923     ) = self._engine.read(  # type: ignore[attr-defined]
#    1924         nrows
#    1925     )
#    1926 except Exception:
#    1927     self.close()
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File pandas/_libs/parsers.pyx:838, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File pandas/_libs/parsers.pyx:921, in pandas._libs.parsers.TextReader._read_rows()
#
# File pandas/_libs/parsers.pyx:991, in pandas._libs.parsers.TextReader._convert_column_data()
#
# ParserError: Defining usecols with out-of-bounds indices is not allowed. [7, 9] are out of bounds.

# %%
#Data Frame z pozostałych danych

df = pd.read_csv(output, header=None)
df.columns = ['Stacja', 'Rok', 'Miesiąc', 'Dzień', 'Maksymalna temperatura', 'Minimalna temperatura', 'Średnia temperatura']
df
# Out:
#            Stacja   Rok  Miesiąc  Dzień  Maksymalna temperatura  \
# 0        PSZCZYNA  2001        1      1                    -1.3
# 1        PSZCZYNA  2001        1      2                     3.3
# 2        PSZCZYNA  2001        1      3                     1.5
# 3        PSZCZYNA  2001        1      4                     6.5
# 4        PSZCZYNA  2001        1      5                     6.5
# ...           ...   ...      ...    ...                     ...
# 1031401    OLECKO  2023       12     27                     5.9
# 1031402    OLECKO  2023       12     28                     3.9
# 1031403    OLECKO  2023       12     29                     5.9
# 1031404    OLECKO  2023       12     30                     6.4
# 1031405    OLECKO  2023       12     31                     3.9
#
#          Minimalna temperatura  Średnia temperatura
# 0                         -9.6                 -5.7
# 1                        -12.0                 -2.7
# 2                         -5.7                 -1.5
# 3                         -1.1                  1.9
# 4                         -2.3                  2.8
# ...                        ...                  ...
# 1031401                    0.2                  2.1
# 1031402                   -1.4                  1.4
# 1031403                    3.0                  4.5
# 1031404                    3.3                  4.5
# 1031405                    0.3                  1.7
#
# [1031406 rows x 7 columns]

# %% [markdown]
# Część 2:
# Polecenie 1 – Znalezienie miast z pełną historią pomiarów

# %%
counts = df["Stacja"].value_counts()

full_hist=[]
for miasto in df["Stacja"]:
    if counts.loc[miasto] == 8400:
        if miasto not in full_hist:
            full_hist.append(miasto)
    else:
        continue

print("Miasta z pełną historią:",full_hist)
# Out:
# Miasta z pełną historią: ['PSZCZYNA', 'BRENNA', 'JABŁONKA', 'ŁAZY', 'JASTRZĘBIA', 'ŁĄCKO', 'KROŚCIENKO', 'NIEDZICA', 'BUKOWINA TATRZAŃSKA', 'DOLINA PIĘCIU STAWÓW', 'SOLINA-JAWOR', 'KOMAŃCZA', 'LGOTA GÓRNA', 'KRAKÓW-OBSERWATORIUM', 'STASZÓW', 'JAROCIN', 'CEBER', 'JARCZEW', 'GORZYŃ', 'WIELICHOWO', 'LEGIONOWO', 'SZEPIETOWO', 'BIAŁOWIEŻA', 'GOLENIÓW', 'CHRZĄSTOWO', 'BIEBRZA-PIEŃCZYKÓWEK', 'RÓŻANYSTOK', 'GDAŃSK-RĘBIECHOWO', 'LIDZBARK WARMIŃSKI']

# %% [markdown]
# Część 2:
# Polecenie 2 – Wykres pomiarów dla wybranej stacji z niepełną historią

# %%
unfull_city = df[df["Stacja"].isin(["PRZEMYŚL"])]

days_per_month = unfull_city.groupby(["Rok","Miesiąc"])["Dzień"].nunique()
counts = days_per_month.unstack(fill_value=0)

for y in range(2001,2024):
    for x in range(1,13):
        if ((unfull_city["Rok"] == y) & (unfull_city["Miesiąc"] == x)).any():
            days = counts.loc[y, x]
            color = "green"
        else:
            color = "red"
            days = 0
        plt.scatter(x, y, color=color, s=100)
        if days>=0:
            plt.text(x, y, str(days), color="black",
                     ha='center', va='center', fontsize=8)


plt.scatter([], [], color="green", s=70, label="Zarejestrowano pomiar")
plt.scatter([], [], color="red", s=70, label="Brak pomiaru")
plt.xticks(ticks=range(1,13), labels=range(1,13))
plt.yticks(ticks=range(2001,2024), labels=range(2001,2024))
plt.xlabel("Miesiąc")
plt.ylabel("Rok")
plt.title("Ilość pomiarów w danym miesiącu w danym roku")
plt.legend()
plt.show()

# %% [markdown]
# Część 2:
# Polecenie 3 – Wykres średniej dziennej temperatury w zależności od liczby dni, jakie upłynęły od 01.01.2001 dla wybranej stacji z pełną historią

# %%
full_city = df[df["Stacja"].isin(["DOLINA PIĘCIU STAWÓW"])]

running_sum = 0
count = 0
running_avr_temp = []

for temp in full_city["Średnia temperatura"]:
    running_sum += temp
    count += 1
    current_mean = running_sum / count
    running_avr_temp.append(current_mean)

# %%
#Sposób 1
plt.plot(running_avr_temp)

# %%
#Sposób 2
plt.plot(full_city["Średnia temperatura"].reset_index(drop=True).expanding().mean())

# %% [markdown]
# Część 2:
# Polecenie 4 – Znalezienie najmniejszej zarejestrowanej temperatury minimalnej i największej zarejestrowanej temperatury maksymalnej

# %%
lowest = df["Minimalna temperatura"].min()
highest = df["Maksymalna temperatura"].max()


lowest_temp = df[df["Minimalna temperatura"] == lowest]
lowest_temp = lowest_temp[["Stacja", "Minimalna temperatura", "Dzień", "Miesiąc", "Rok"]]
highest_temp = df[df["Maksymalna temperatura"] == highest]
highest_temp = highest_temp[["Stacja", "Maksymalna temperatura", "Dzień", "Miesiąc", "Rok"]]

# %%
lowest_temp
# Out:
#           Stacja  Minimalna temperatura  Dzień  Miesiąc   Rok
# 870241  JABŁONKA                  -37.3      8        1  2017

# %%
highest_temp
# Out:
#        Stacja  Maksymalna temperatura  Dzień  Miesiąc   Rok
# 831911  CEBER                    39.0      8        8  2015

# %% [markdown]
# Część 2:
# Polecenie 5b – Wykres średniej temperatury miesięcznej dla każdego miesiąca każdego roku

# %%
full_city = df[df["Stacja"].isin(["DOLINA PIĘCIU STAWÓW"])]

avg_multi_group = (full_city.groupby(['Rok', 'Miesiąc'])['Średnia temperatura'].mean()).to_frame().reset_index()
avg_multi_group
# Out:
#       Rok  Miesiąc  Średnia temperatura
# 0    2001        1            -5.012903
# 1    2001        2            -6.567857
# 2    2001        3            -2.367742
# 3    2001        4            -0.276667
# 4    2001        5             6.138710
# ..    ...      ...                  ...
# 271  2023        8            13.400000
# 272  2023        9            10.700000
# 273  2023       10             5.651613
# 274  2023       11            -2.656667
# 275  2023       12            -2.554839
#
# [276 rows x 3 columns]

# %%
norm = plt.Normalize(vmin=avg_multi_group['Średnia temperatura'].min(), vmax=avg_multi_group['Średnia temperatura'].max())
sm = plt.cm.ScalarMappable(cmap='coolwarm', norm=norm)

avg_multi_group['Miesiąc'] = avg_multi_group['Miesiąc'].apply(lambda x: calendar.month_name[x])

for month in avg_multi_group['Miesiąc'].unique():
    month_data = avg_multi_group[avg_multi_group['Miesiąc'] == month]
    fig, ax = plt.subplots(figsize=(15, 7))

    colors = [sm.to_rgba(val) for val in month_data['Średnia temperatura']]

    sns.barplot(data=month_data, 
                 x='Rok',  
                 y='Średnia temperatura',
                 palette=colors,
                 hue='Rok',
                 legend=False
                 )
    
    fig.colorbar(sm, ax=ax, label='Temperature (°C)')
    plt.title(f"Dolina Pięciu Stawów – {month}")
    plt.show()

# %% [markdown]
# Część 3:
# Wykrywanie anomalii

# %%
df['delta'] = df['Maksymalna temperatura'] - df['Minimalna temperatura']

df[df['delta'] >= 30].sort_values(by='delta', ascending=False)
# Out:
#             Stacja   Rok  Miesiąc  Dzień  Maksymalna temperatura  \
# 235998  STUPOSIANY  2005        2      8                     0.3
# 235999  STUPOSIANY  2005        2      9                     2.9
# 235997  STUPOSIANY  2005        2      7                    -0.6
# 167516    JABŁONKA  2003       12     26                    14.4
# 235941    KOMAŃCZA  2005        2      7                     3.0
# 235943    KOMAŃCZA  2005        2      9                     4.9
# 235942    KOMAŃCZA  2005        2      8                     4.1
# 236000  STUPOSIANY  2005        2     10                     1.4
#
#         Minimalna temperatura  Średnia temperatura  delta
# 235998                  -32.3                -20.5   32.6
# 235999                  -29.4                -17.5   32.3
# 235997                  -32.7                -21.1   32.1
# 167516                  -17.6                 -3.3   32.0
# 235941                  -28.9                -17.7   31.9
# 235943                  -26.3                -15.2   31.2
# 235942                  -26.7                -15.8   30.8
# 236000                  -28.8                -15.3   30.2
